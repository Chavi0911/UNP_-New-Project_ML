# %% [markdown]
# MATPLOTLIB

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Copy of Insurance.csv")

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# RENAME

# %%
data.rename(columns = {'age':'Age'},inplace = True)
data.rename(columns = {'sex':'Sex'},inplace = True)
data.rename(columns = {'bmi':'Bmi'},inplace = True)
data.rename(columns = {'children':'Children'},inplace = True)
data.rename(columns = {'smoker':'Smoker'},inplace = True)
data.rename(columns = {'region':'Region'},inplace = True)
data.rename(columns = {'charge':'Charge'},inplace = True)

# %%
data
# Out:
#       Age     Sex     Bmi  Children Smoker     Region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data['Region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
data['Region']=data['Region'].str.replace('southeast','Southern East').str.replace('southwest','Southern West').str.replace('northwest','Northern West').str.replace('northeast','northerneast')

# %%
data['Region'].unique()
# Out:
# array(['Southern West', 'Southern East', 'Northern West', 'northerneast'],
#       dtype=object)

# %%
data
# Out:
#       Age     Sex     Bmi  Children Smoker         Region      charges
# 0      19  female  27.900         0    yes  Southern West  16884.92400
# 1      18    male  33.770         1     no  Southern East   1725.55230
# 2      28    male  33.000         3     no  Southern East   4449.46200
# 3      33    male  22.705         0     no  Northern West  21984.47061
# 4      32    male  28.880         0     no  Northern West   3866.85520
# ...   ...     ...     ...       ...    ...            ...          ...
# 1333   50    male  30.970         3     no  Northern West  10600.54830
# 1334   18  female  31.920         0     no   northerneast   2205.98080
# 1335   18  female  36.850         0     no  Southern East   1629.83350
# 1336   21  female  25.800         0     no  Southern West   2007.94500
# 1337   61  female  29.070         0    yes  Northern West  29141.36030
#
# [1338 rows x 7 columns]

# %%
data['Sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
data['Sex'] = data.Sex.map({'female' :0,'male' :1})

# %%
data['Sex'].unique()
# Out:
# array([0, 1])

# %%
data['Smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data['Smoker'] = data.Smoker.map({'yes':1,'no':0})

# %%
data['Smoker'].unique()
# Out:
# array([1, 0])

# %%
data
# Out:
#       Age  Sex     Bmi  Children  Smoker         Region      charges
# 0      19    0  27.900         0       1  Southern West  16884.92400
# 1      18    1  33.770         1       0  Southern East   1725.55230
# 2      28    1  33.000         3       0  Southern East   4449.46200
# 3      33    1  22.705         0       0  Northern West  21984.47061
# 4      32    1  28.880         0       0  Northern West   3866.85520
# ...   ...  ...     ...       ...     ...            ...          ...
# 1333   50    1  30.970         3       0  Northern West  10600.54830
# 1334   18    0  31.920         0       0   northerneast   2205.98080
# 1335   18    0  36.850         0       0  Southern East   1629.83350
# 1336   21    0  25.800         0       0  Southern West   2007.94500
# 1337   61    0  29.070         0       1  Northern West  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# REPLACE

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (1337, 7)

# %%
data['Bmi'] = pd.to_numeric(data['Bmi'], errors = 'coerce')

# %%
data
# Out:
#       Age  Sex     Bmi  Children  Smoker         Region      charges
# 0      19    0  27.900         0       1  Southern West  16884.92400
# 1      18    1  33.770         1       0  Southern East   1725.55230
# 2      28    1  33.000         3       0  Southern East   4449.46200
# 3      33    1  22.705         0       0  Northern West  21984.47061
# 4      32    1  28.880         0       0  Northern West   3866.85520
# ...   ...  ...     ...       ...     ...            ...          ...
# 1333   50    1  30.970         3       0  Northern West  10600.54830
# 1334   18    0  31.920         0       0   northerneast   2205.98080
# 1335   18    0  36.850         0       0  Southern East   1629.83350
# 1336   21    0  25.800         0       0  Southern West   2007.94500
# 1337   61    0  29.070         0       1  Northern West  29141.36030
#
# [1337 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       1337 non-null   int64
#  1   Sex       1337 non-null   int64
#  2   Bmi       1337 non-null   float64
#  3   Children  1337 non-null   int64
#  4   Smoker    1337 non-null   int64
#  5   Region    1337 non-null   object
#  6   charges   1337 non-null   float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 83.6+ KB

# %%
data.isnull()
# Out:
#         Age    Sex    Bmi  Children  Smoker  Region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1337 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# Age         0
# Sex         0
# Bmi         0
# Children    0
# Smoker      0
# Region      0
# charges     0
# dtype: int64

# %%
data.head(3)
# Out:
#    Age  Sex    Bmi  Children  Smoker         Region     charges
# 0   19    0  27.90         0       1  Southern West  16884.9240
# 1   18    1  33.77         1       0  Southern East   1725.5523
# 2   28    1  33.00         3       0  Southern East   4449.4620

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(x='Bmi', data=data)
# Out:
# <Axes: xlabel='Bmi'>

# %%
q3 = data['Bmi'].quantile(.75)
q1 = data['Bmi'].quantile(.25)
iqr = q3-q1
iqr
# Out:
# np.float64(8.410000000000004)

# %%
upperrange = q3+1.5*iqr
bottomrange = q1-1.5*iqr
data = data[(data['Bmi']>bottomrange) & (data['Bmi']<upperrange)]
sns.boxplot(data=data,x='Bmi')
# Out:
# <Axes: xlabel='Bmi'>

# %%
sns.boxplot(x='charges', data=data)
# Out:
# <Axes: xlabel='charges'>

# %%
q3 = data['charges'].quantile(.75)
q1 = data['charges'].quantile(.25)
iqr = q3-q1
iqr
# Out:
# np.float64(11859.977595)

# %%
upperrange = q3+1.5*iqr
bottomrange = q1-1.5*iqr
data = data[(data['charges']>bottomrange) & (data['charges']<upperrange)]
sns.boxplot(data=data,x='charges')
# Out:
# <Axes: xlabel='charges'>

# %%
data
# Out:
#       Age  Sex     Bmi  Children  Smoker         Region      charges
# 0      19    0  27.900         0       1  Southern West  16884.92400
# 1      18    1  33.770         1       0  Southern East   1725.55230
# 2      28    1  33.000         3       0  Southern East   4449.46200
# 3      33    1  22.705         0       0  Northern West  21984.47061
# 4      32    1  28.880         0       0  Northern West   3866.85520
# ...   ...  ...     ...       ...     ...            ...          ...
# 1333   50    1  30.970         3       0  Northern West  10600.54830
# 1334   18    0  31.920         0       0   northerneast   2205.98080
# 1335   18    0  36.850         0       0  Southern East   1629.83350
# 1336   21    0  25.800         0       0  Southern West   2007.94500
# 1337   61    0  29.070         0       1  Northern West  29141.36030
#
# [1190 rows x 7 columns]

# %% [markdown]
# DUMMIFICATION

# %%
data_dummies = pd.get_dummies(data['Region'], prefix='Region')

# %%
data_dummies
# Out:
#       Region_Northern West  Region_Southern East  Region_Southern West  \
# 0                    False                 False                  True
# 1                    False                  True                 False
# 2                    False                  True                 False
# 3                     True                 False                 False
# 4                     True                 False                 False
# ...                    ...                   ...                   ...
# 1333                  True                 False                 False
# 1334                 False                 False                 False
# 1335                 False                  True                 False
# 1336                 False                 False                  True
# 1337                  True                 False                 False
#
#       Region_northerneast
# 0                   False
# 1                   False
# 2                   False
# ...

# %%
data
# Out:
#       Age  Sex     Bmi  Children  Smoker         Region      charges
# 0      19    0  27.900         0       1  Southern West  16884.92400
# 1      18    1  33.770         1       0  Southern East   1725.55230
# 2      28    1  33.000         3       0  Southern East   4449.46200
# 3      33    1  22.705         0       0  Northern West  21984.47061
# 4      32    1  28.880         0       0  Northern West   3866.85520
# ...   ...  ...     ...       ...     ...            ...          ...
# 1333   50    1  30.970         3       0  Northern West  10600.54830
# 1334   18    0  31.920         0       0   northerneast   2205.98080
# 1335   18    0  36.850         0       0  Southern East   1629.83350
# 1336   21    0  25.800         0       0  Southern West   2007.94500
# 1337   61    0  29.070         0       1  Northern West  29141.36030
#
# [1190 rows x 7 columns]

# %% [markdown]
# NEW SECTION

# %%
sns.boxplot(x = data['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
data.boxplot(figsize=(25,10))
# Out:
# <Axes: >

# %%
# Draw histograms for each column in the dataset
numerical_data = data.select_dtypes(include=np.number) # Select only numerical columns
num_columns = numerical_data.shape[1]
num_rows = (num_columns + 1) // 2 #Calculate the number of rows for subplots

fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(12, num_rows * 4)) # Adjust figsize based on num_rows

# Flatten axes if multiple rows are used
axes = axes.flatten()

for i, column in enumerate(numerical_data.columns): # Iterate over numerical columns
   numerical_data[column].hist(ax=axes[i], bins=20)  #Adjust bins as needed
   axes[i].set_title(f"{column}")
   axes[i].set_xlabel(column)
   axes[i].set_ylabel("Frequency")

# If there's an odd number of column, remove the empty subplot
if num_columns % 2 !=0:
    fig.delaxes(axes[num_columns]) # Remove the empty subplot based on the actual number of numerical columns

plt.tight_layout()  #Adjust layout for spacing between subplots
plt.show()

# %%
sns.pairplot(data[['Age', 'Bmi','Children', 'charges', 'Sex', 'Smoker']])
plt.show()

# %%
sns.barplot(x='Sex', y='charges', data=data , hue='Smoker')
plt.show()

# %%
sns.scatterplot(x='Age', y='charges', data=data)
plt.show()

# %%
Sex_counts = data['Sex'].value_counts()
plt.figure(figsize=(12,5))
labels = ['Female', 'Male']
plt.pie(Sex_counts, labels=labels, autopct='%1.1f%%', colors=['skyblue', 'lightcoral']) # Changed 'colours' to 'colors'
plt.title('Distribution of Sex')
# Out:
# Text(0.5, 1.0, 'Distribution of Sex')

# %%
numerical_data = data.select_dtypes(include=np.number)
correlation_matrix = numerical_data.corr()
print(correlation_matrix)
# Out:
#                Age       Sex       Bmi  Children    Smoker   charges
# Age       1.000000 -0.020240  0.124055  0.037153 -0.062581  0.448052
# Sex      -0.020240  1.000000  0.016407  0.016346  0.014343 -0.021925
# Bmi       0.124055  0.016407  1.000000  0.007625 -0.260642 -0.064421
# Children  0.037153  0.016346  0.007625  1.000000 -0.002172  0.088297
# Smoker   -0.062581  0.014343 -0.260642 -0.002172  1.000000  0.596230
# charges   0.448052 -0.021925 -0.064421  0.088297  0.596230  1.000000

# %%
zheatmap = sns.heatmap(data.select_dtypes(include=np.number).corr(), annot=True, cmap="coolwarm", linewidths=.5)
plt.title("correlation Heatmap")
plt.show()

# %% [markdown]
# LINEAR REGRESSION

# %%
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
data = pd.concat([data, data_dummies], axis=1)

# %%
data = data.drop(['Region_northerneast','Region'], axis=1)

# %%
data
# Out:
#       Age  Sex     Bmi  Children  Smoker      charges  Region_Northern West  \
# 0      19    0  27.900         0       1  16884.92400                 False
# 1      18    1  33.770         1       0   1725.55230                 False
# 2      28    1  33.000         3       0   4449.46200                 False
# 3      33    1  22.705         0       0  21984.47061                  True
# 4      32    1  28.880         0       0   3866.85520                  True
# ...   ...  ...     ...       ...     ...          ...                   ...
# 1333   50    1  30.970         3       0  10600.54830                  True
# 1334   18    0  31.920         0       0   2205.98080                 False
# 1335   18    0  36.850         0       0   1629.83350                 False
# 1336   21    0  25.800         0       0   2007.94500                 False
# 1337   61    0  29.070         0       1  29141.36030                  True
#
#       Region_Southern East  Region_Southern West
# ...

# %%
feature_cols = ['Age','Sex','Bmi','Children','Smoker','Region_Northern West','Region_Southern East','Region_Southern West']
X = data[feature_cols]
Y = data[['charges']]

lm2 = LinearRegression()
lm2.fit(X,Y)

print(lm2.intercept_)
print(lm2.coef_)
# Out:
# [-2968.85514326]
# [[  244.46930086  -346.05888172    69.20050596   433.08831829
#   14391.32962104  -288.51104458 -1083.18961923 -1392.67930331]]

# %%
lm2.predict([[50, 1, 25, 0, 0, 0, 0, 0]]) # Added dummy variables for regions
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[10638.56366681]])

# %%
sns.pairplot(data, x_vars=['Age','Sex','Bmi','Children','Smoker','Region_Northern West','Region_Southern East','Region_Southern West'], y_vars=['charges'], size=7, aspect=0.7, kind='reg')
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
lm2.score(X,Y)
# Out:
# 0.6052178612960789

# %%
{i:j for i,j in zip(feature_cols, lm2.coef_)}
# Out:
# {'Age': array([  244.46930086,  -346.05888172,    69.20050596,   433.08831829,
#         14391.32962104,  -288.51104458, -1083.18961923, -1392.67930331])}

# %%
x = data[['Age','Sex','Bmi','Children','Smoker','Region_Northern West','Region_Southern East','Region_Southern West']]
y = data[['charges']]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=1)
lm2 = LinearRegression()
lm2.fit(X_train, Y_train)
Y_pred = lm2.predict(X_test)
print(np.sqrt(metrics.mean_squared_error(Y_test, Y_pred)))
# Out:
# 4721.400563529604

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, Y_pred)
# Out:
# 0.5631214737527754

# %% [markdown]
# KNN REGRESSOR

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = .3, random_state = 46)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model=KNeighborsRegressor(n_neighbors=5)

# %%
model.fit(X_train, Y_train)
# Out:
# KNeighborsRegressor()

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred
# Out:
# array([[14164.99199  ],
#        [ 8206.89232  ],
#        [14895.015254 ],
#        [ 5153.446506 ],
#        [13404.03001  ],
#        [ 2038.63163  ],
#        [14591.13149  ],
#        [15433.227672 ],
#        [ 1528.82209  ],
#        [ 4132.43842  ],
#        [ 6827.205572 ],
#        [ 5712.25072  ],
#        [10447.114858 ],
#        [ 8868.61566  ],
#        [ 5982.79648  ],
#        [ 4238.86726  ],
#        [14687.84549  ],
#        [11215.85313  ],
#        [15653.071422 ],
#        [ 7227.71375  ],
#        [ 8441.073    ],
#        [ 9247.354258 ],
#        [ 4117.46022  ],
#        [ 8169.14457  ],
#        [ 9848.92308  ],
#        [10259.52651  ],
#        [13518.94608  ],
#        [ 4634.6312   ],
#        [13067.809492 ],
#        [13355.38139  ],
#        [ 9617.32856  ],
#        [10226.74735  ],
#        [10912.34555  ],
#        [12940.754732 ],
#        [ 6870.28169  ],
#        [ 3234.32406  ],
#        [14372.936844 ],
#        [17659.546932 ],
# ...

# %%
# Iterate through the columns and create a DataFrame for each region
for col in Y_test.columns:
    knn = pd.DataFrame({'Predicted': Y_pred[:, Y_test.columns.get_loc(col)], 'Actual': Y_test[col]})
    print(f"Comparison for {col}:")
    display(knn.head()) # Display the head of each comparison DataFrame
# Out:
# Comparison for charges:
#         Predicted       Actual
# 768  14164.991990  14319.03100
# 339   8206.892320   8232.63880
# 156  14895.015254  21223.67580
# 358   5153.446506   1837.28190
# 813  13404.030010   4428.88785

# %%
knn
# Out:
#         Predicted       Actual
# 768  14164.991990  14319.03100
# 339   8206.892320   8232.63880
# 156  14895.015254  21223.67580
# 358   5153.446506   1837.28190
# 813  13404.030010   4428.88785
# ..            ...          ...
# 133   2294.029280   1632.56445
# 821   8159.370380   2680.94930
# 51    7468.679174   3579.82870
# 648   4641.034432   1712.22700
# 366  15044.127852  13430.26500
#
# [357 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, Y_pred)
# Out:
# 0.17823615792544356

# %%
from sklearn import metrics
metrics.mean_absolute_error(Y_test, Y_pred)
# Out:
# 4518.356921567507

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test,Y_pred)
# Out:
# 46046124.029256955

# %%
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(6785.72943973284)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(Y_test, Y_pred)
print(mape)
mape = mape*100
mape
# Out:
# 0.6072004422666804
# 60.72004422666804

# %%
plt.scatter(X_test['Age'], Y_test, label='Test Data')
plt.scatter(X_test['Age'], Y_pred, color='red', linewidth=1, label='KNN points')
plt.xlabel('Age')
plt.ylabel('Copy of insurance')
plt.title('KNN Regression')
plt.legend()
plt.show()

# %% [markdown]
# SVR REGRESSOR

# %%
from sklearn.svm import SVR

# %%
model = SVR(kernel='linear')

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='linear')

# %%
Y_pred = model.predict(X_test)

# %%
Y_pred
# Out:
# array([13338.34890578,  9036.40399433,  9455.23327878,  2312.33029783,
#         4513.81467993,  2062.69682511, 11908.07311118, 12161.65424433,
#         1486.21647757,  4329.75097225,  2857.34085056,  6174.50751354,
#         7696.74010757,  4496.30128403,  3916.63437226,  5006.84060391,
#        13536.96403912,  9151.11180305, 12404.25164578,  3900.75284489,
#         3830.11835103,  1924.72492421,  3881.53341177,  6046.7010846 ,
#         8098.02244115,  5257.04165527, 12574.12548132,  1775.83267764,
#         8065.11578333,  8639.88635497, 10020.4908265 ,  4996.84104282,
#        11157.91606001, 10640.49529391,  7659.96531302,  3807.54755955,
#         9357.67343047,  8586.43150066,  9959.57433024,  2097.63039886,
#         4455.55694066,  3635.81822896, 12637.16366098,  7632.06972057,
#        12783.87027886, 11287.19499187,  2807.02208374,  8744.20587551,
#         6852.07759815, 11565.46966763,  6149.11519296,  1772.06383559,
# ...

# %%
svm = pd.DataFrame({'Predicted':Y_pred,'Actual':Y_test.values.flatten()})
svm
# Out:
#         Predicted       Actual
# 0    13338.348906  14319.03100
# 1     9036.403994   8232.63880
# 2     9455.233279  21223.67580
# 3     2312.330298   1837.28190
# 4     4513.814680   4428.88785
# ..            ...          ...
# 352   1630.436599   1632.56445
# 353   3669.376297   2680.94930
# 354   2482.007843   3579.82870
# 355   1285.386074   1712.22700
# 356  12058.818627  13430.26500
#
# [357 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, Y_pred)
# Out:
# 0.027875943830675376

# %%
from sklearn import metrics
metrics.mean_absolute_error(Y_test,Y_pred)
# Out:
# 3731.582514466458

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test, Y_pred)
# Out:
# 54471300.11122574

# %%
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(7380.46747240483)

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(Y_test, Y_pred)
print(mape)
mape = mape*100
mape
# Out:
# 0.24227204667296823
# 24.227204667296824

# %%
plt.scatter(X_test['Age'], Y_test, label='Test Data')
plt.scatter(X_test['Age'], Y_pred, color='red', linewidth=1, label='SVM points')
plt.xlabel('Age')
plt.ylabel('Copy of insurance')
plt.title('SVM Regression')
plt.legend()
plt.show()

# %% [markdown]
# DECISION TREE REGRESSOR

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
feature_cols = ['Age','Sex','Bmi','Children','Smoker','Region_Northern West','Region_Southern East','Region_Southern West']
X = data[feature_cols]
Y = data["charges"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
reg = DecisionTreeRegressor()

reg = reg.fit(X_train, Y_train)

# %%
Y_pred = reg.predict(X_test)

# %%
print(f"mean squared error:{mse:.4f}")
# Out:
# mean squared error:54471300.1112

# %%
reg = DecisionTreeRegressor(criterion="squared_error", max_depth=3)
reg = reg.fit(X_train,Y_train)
Y_pred = reg.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
print(f"mean squared error:{mse:.4f}")
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# mean squared error:21550937.3803
# np.float64(4642.298717261271)

# %%
reg = DecisionTreeRegressor(criterion="poisson", max_depth=6)
reg = reg.fit(X_train,Y_train)
Y_pred = reg.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
print(f"mean squared error:{mse:.4f}")
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# mean squared error:22507232.9478
# np.float64(4744.178848635763)

# %%
reg = DecisionTreeRegressor(criterion="squared_error", max_depth=2)
reg = reg.fit(X_train,Y_train)
Y_pred = reg.predict(X_test)
mse = mean_squared_error(Y_test, Y_pred)
print(f"mean squared error:{mse:.4f}")
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# mean squared error:24121997.3737
# np.float64(4911.415007272791)

# %%
Y_pred_train = reg.predict(X_train)

# %%
reg = DecisionTreeRegressor(criterion="squared_error", max_depth=2)
reg = reg.fit(X_train,Y_train)
Y_pred = reg.predict(X_test)
Y_pred_train = reg.predict(X_train) # Recalculate Y_pred_train after the split
mse = mean_squared_error(Y_train, Y_pred_train)
print(f"mean squared error:{mse:.4f}")
mse = mean_squared_error(Y_train, Y_pred_train)
rmse = np.sqrt(mse)
rmse
# Out:
# mean squared error:21582512.6153
# np.float64(4645.698291459927)

# %% [markdown]
# RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import plot_tree
from matplotlib import pyplot as plt

# %%
# Use the existing X and Y variables
x = X
y = Y

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (714, 8)
# (714,)
# (476, 8)
# (476,)

# %%
dt = DecisionTreeRegressor()

# %%
dt.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
rf = RandomForestRegressor()

# %%
rf.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ADABOOST

# %%
feature_cols = ['Age','Sex','Bmi','Children','Smoker','Region_Northern West','Region_Southern East','Region_Southern West']
target_col = ['charges']

# %%
data, target = data[feature_cols], data[target_col]

# %%
tree = DecisionTreeRegressor(max_depth=2, random_state=0)
tree.fit(data, target)
# Out:
# DecisionTreeRegressor(max_depth=2, random_state=0)

# %%
target_predicted = tree.predict(data)

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
base_estimator = DecisionTreeRegressor(max_depth=3, random_state=0)
adaboost = AdaBoostRegressor(estimator=base_estimator, n_estimators=3, random_state=0)
adaboost.fit(data, target)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# AdaBoostRegressor(estimator=DecisionTreeRegressor(max_depth=3, random_state=0),
#                   n_estimators=3, random_state=0)

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
import numpy as np

# Assuming X and Y are already defined from previous steps
# Perform train-test split (using the same split as the previous RandomForestRegressor and XGBoost for consistency)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=42)


# Define the base estimator
base_estimator = DecisionTreeRegressor(max_depth=3, random_state=0)

# Instantiate the AdaBoostRegressor model
adaboost = AdaBoostRegressor(estimator=base_estimator, n_estimators=100, random_state=0)

# Fit the model to the training data
adaboost.fit(X_train, Y_train)

# Make predictions on the test data
Y_pred = adaboost.predict(X_test)

# Calculate evaluation metrics
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(Y_test, Y_pred)
mae = mean_absolute_error(Y_test, Y_pred)
mape = mean_absolute_percentage_error(Y_test, Y_pred) * 100

print(f"Mean Squared Error: {mse:.4f}")
print(f"Root Mean Squared Error: {rmse:.4f}")
print(f"R-squared: {r2:.4f}")
print(f"Mean Absolute Error: {mae:.4f}")
print(f"Mean Absolute Percentage Error: {mape:.4f}%")
# Out:
# Mean Squared Error: 27302455.6859
# Root Mean Squared Error: 5225.1752
# R-squared: 0.4603
# Mean Absolute Error: 4327.0528
# Mean Absolute Percentage Error: 79.3391%

# %% [markdown]
# XGBOOST

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split

# %%
model1 = xgb.XGBRegressor()
model2 = xgb.XGBRegressor(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)

train_model1 = model1.fit(X_train, Y_train)
train_model2 = model2.fit(X_train, Y_train)

# %%
pred1 = train_model1.predict(X_test)
pred2 = train_model2.predict(X_test)
# Calculate and print the RMSE for both models
rmse1 = np.sqrt(mean_squared_error(Y_test, pred1))
rmse2 = np.sqrt(mean_squared_error(Y_test, pred2))

print(f'Model 1 XGBoost RMSE: {rmse1:.4f}')
print(f'Model 2 XGBoost RMSE: {rmse2:.4f}')
# Out:
# Model 1 XGBoost RMSE: 5315.3696
# Model 2 XGBoost RMSE: 5127.5094

# %%
from sklearn.metrics import r2_score

r2_model1 = r2_score(Y_test, pred1)
r2_model2 = r2_score(Y_test, pred2)

print(f"R-squared for model 1: {r2_model1:.4f}")
print(f"R-squared for model 2: {r2_model2:.4f}")
# Out:
# R-squared for model 1: 0.4415
# R-squared for model 2: 0.4802

# %%
xgb2 = xgb.XGBRegressor(learning_rate=0.7, n_estimators=1000, max_depth=4,
                        min_child_weight=6,
                        subsample=0.8,
                        colsample_bytree=0.8, objective= 'reg:squarederror',
                        nthread=4, scale_pos_weight=1, seed=27)
train_model7 = xgb2.fit(X_train, Y_train)
pred7 = train_model7.predict(X_test)
print("Acurracy for model 7: %.2f" % (r2_score(Y_test, pred7) * 100))
# Out:
# Acurracy for model 7: 30.64

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score # Import r2_score

rfr = RandomForestRegressor()
rfr_model = rfr.fit(X_train, Y_train)
pred8 = rfr_model.predict(X_test)
print("R-squared for Random Forest Model: %.2f" % (r2_score(Y_test, pred8) * 100)) # Use r2_score instead of accuracy_score
# Out:
# R-squared for Random Forest Model: 51.65

# %%
rfr = RandomForestRegressor()
rfr_model = rfr.fit(X_train, Y_train)
pred8 = rfr_model.predict(X_test)
print("Accuracy  for Random Forest Model: %.2f" % (r2_score(Y_test, pred8) * 100))
# Out:
# Accuracy  for Random Forest Model: 53.14

# %%
import xgboost as xgb # Import xgboost library
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
import numpy as np

# Assuming X and Y are already defined from previous steps
# Perform train-test split (using the same split as the previous RandomForestRegressor and XGBoost for consistency)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=42)


# Define the base estimator
base_estimator = DecisionTreeRegressor(max_depth=3, random_state=0)

# Instantiate the AdaBoostRegressor model
xgboost = xgb.XGBRegressor(estimator=base_estimator, n_estimators=100, random_state=0)

# Fit the model to the training data
xgboost.fit(X_train, Y_train)

# Make predictions on the test data
Y_pred = xgboost.predict(X_test)

# Calculate evaluation metrics
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(Y_test, Y_pred)
mae = mean_absolute_error(Y_test, Y_pred)
mape = mean_absolute_percentage_error(Y_test, Y_pred) * 100

print(f"Mean Squared Error: {mse:.4f}")
print(f"Root Mean Squared Error: {rmse:.4f}")
print(f"R-squared: {r2:.4f}")
print(f"Mean Absolute Error: {mae:.4f}")
print(f"Mean Absolute Percentage Error: {mape:.4f}%")
# Out:
# Mean Squared Error: 28253154.1819
# Root Mean Squared Error: 5315.3696
# R-squared: 0.4415
# Mean Absolute Error: 3037.6996
# Mean Absolute Percentage Error: 44.5437%
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [13:18:32] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "estimator" } are not used.
#
#   warnings.warn(smsg, UserWarning)
